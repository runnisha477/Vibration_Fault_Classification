# %%
# mencari directory saat ini
import os
os.getcwd()
# Out:
# 'C:\\Users\\KOMPUTER\\Documents\\Jupyter Notebooks'

# %%
# Merubah directory
os.chdir('D:\\ITS\\Tugas Akhir\\Source Code')
# Merubah directory (beneran)
os.chdir('D:/ITS/Tugas Akhir/Source Code')

# %%
import numpy as np
import pandas as pd
import glob

# %%
cur_path = "D:/ITS/Tugas Akhir/data/Endaq CSV/"

# %%
normal_file_names = glob.glob(cur_path+'/normal/*.csv')
imnormal_misalignment = glob.glob(cur_path+'/misalignment/*.csv')
imnormal_unbalance = glob.glob(cur_path+'/unbalance/*.csv')
imnormal_bearing = glob.glob(cur_path+'/bearing/*.csv')

# %%
def dataReader(path_names):
    data_n = pd.DataFrame()
    for i in path_names:
        low_data = pd.read_csv(i,header=None)
        data_n = pd.concat([data_n,low_data],ignore_index=True)
    return data_n

# %%
data_normal = dataReader(normal_file_names)
data_misalignment = dataReader(imnormal_misalignment)
data_unbalance = dataReader(imnormal_unbalance)
data_bearing = dataReader(imnormal_bearing)

# %%
# DOWN SAMPLING

def downSampler(data,a,b):
    """
    data = data
    a = start index
    b = sampling rate
    """
    data_decreased = pd.DataFrame()
    x = b
    for i in range(int(len(data)/x)):
        data_decreased = data_decreased.append(data.iloc[a:b,:].sum()/x,ignore_index=True)
        a += x
        b += x
    return data_decreased

# %%
data_normal = downSampler(data_normal, 0, 5000)
data_misalignment = downSampler(data_misalignment, 0, 5000)
data_unbalance = downSampler(data_unbalance, 0, 5000)
data_bearing = downSampler(data_bearing, 0, 5000)

# %%
data_misalignment
# Out:
#             0         1         2         3
# 0    0.130474  0.012886  0.009876 -0.010109
# 1    0.380527  0.026833  0.028392 -0.016349
# 2    0.630527 -0.007332 -0.015320 -0.013292
# 3    0.880534  0.015834  0.023270 -0.004290
# 4    1.130533 -0.000268  0.000020 -0.005971
# ..        ...       ...       ...       ...
# 993  3.663596  0.005334  0.009432 -0.003525
# 994  3.913604 -0.006480 -0.014145  0.000059
# 995  4.163604  0.025339  0.029569  0.000994
# 996  4.413611 -0.007813 -0.020164 -0.000312
# 997  4.663608  0.012233  0.013349  0.013716
#
# [998 rows x 4 columns]

# %%
len(data_misalignment)
# Out:
# 998

# %%
# FFT

from scipy import signal
def FFT(data):
    autocorr = signal.fftconvolve(data,data[::-1],mode='full')
    return pd.DataFrame(autocorr)

# %%
data_normal = FFT(data_normal)
data_misalignment = FFT(data_misalignment)
data_unbalance = FFT(data_unbalance)
data_bearing = FFT(data_bearing)

# %%
y_1 = pd.DataFrame(np.full((int(len(data_normal)),1),0))
y_2 = pd.DataFrame(np.full((int(len(data_misalignment)),1),1))
y_3 = pd.DataFrame(np.full((int(len(data_unbalance)),1),2))
y_4 = pd.DataFrame(np.full((int(len(data_bearing)),1),3))
y = pd.concat([y_1,y_2,y_3,y_4], ignore_index=True)
y
# Out:
#        0
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ...   ..
# 12153  3
# 12154  3
# 12155  3
# 12156  3
# 12157  3
#
# [12158 rows x 1 columns]

# %%
data = pd.concat([data_normal,data_misalignment,data_unbalance,data_bearing],ignore_index=True)

# %%
data
# Out:
#                0         1         2         3         4             5  \
# 0       0.623005  0.067794  0.091318 -0.073082 -0.000054 -4.094008e-05
# 1       2.421297  0.107115  0.143096 -0.113841 -0.000011 -1.747493e-04
# 2       5.332108  0.164318  0.196033 -0.178904 -0.000081 -2.288879e-04
# 3       9.292989  0.175975  0.236218 -0.186550 -0.000127 -3.708794e-04
# 4      14.241381  0.203066  0.261488 -0.214558 -0.000054 -2.388535e-04
# ...          ...       ...       ...       ...       ...           ...
# 12153  13.911024  0.389112  0.279515 -0.191630 -0.002046  5.075877e-07
# 12154   9.099801  0.311068  0.265596 -0.169323 -0.001052  1.433499e-04
# 12155   5.240580  0.299905  0.243329 -0.169188  0.000163  2.534752e-04
# 12156   2.395820  0.213578  0.196326 -0.130663  0.000337  2.986973e-04
# 12157   0.628054  0.107702  0.097804 -0.042248  0.000117  1.337272e-04
#
#               6
# 0     -0.000001
# 1      0.000053
# 2      0.000073
# 3      0.000153
# 4      0.000040
# ...         ...
# 12153 -0.000039
# 12154 -0.000063
# 12155 -0.000143
# 12156 -0.000143
# 12157 -0.000045
#
# [12158 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.2, shuffle=True)

# %%
print("Shape of Train Data : {}".format(X_train.shape))
print("Shape of Test Data : {}".format(X_test.shape))
# Out:
# Shape of Train Data : (9726, 7)
# Shape of Test Data : (2432, 7)

# %%
import tensorflow as tf
X_train = tf.expand_dims(X_train, axis=-1)
X_test = tf.expand_dims(X_test, axis=-1)

print("Shape of Train Data : {}".format(X_train.shape))
print("Shape of Test Data : {}".format(X_test.shape))
# Out:
# Shape of Train Data : (9726, 7, 1)
# Shape of Test Data : (2432, 7, 1)

# %%
import keras
from keras import models
from keras import layers


input_shape=(7,1)

model = models.Sequential()
model.add(layers.Conv1D(128, 2, input_shape=input_shape , activation='relu'))
model.add(layers.Conv1D(128, 2, activation='relu'))
model.add(layers.Conv1D(96, 2, activation='relu'))
model.add(layers.Conv1D(64, 2, activation='relu'))
model.add(layers.GlobalMaxPooling1D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 6, 128)            384
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 5, 128)            32896
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 4, 96)             24672
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 3, 64)             12352
# _________________________________________________________________
# global_max_pooling1d (Global (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 260
# =================================================================
# Total params: 70,564
# Trainable params: 70,564
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#from sklearn.preprocessing import LabelEncoder
#y = LabelEncoder().fit_transform(y)

# %%
hist = model.fit(X_train , y_train , epochs=200, validation_split=0.2)
#batch_size = 25
#num_epochs = 100
#hist = model.fit(X_train, y_train, batch_size=batch_size, epochs=num_epochs, )
# Out:
# Epoch 1/200
# 244/244 [==============================] - 1s 5ms/step - loss: 3.6211 - accuracy: 0.7211 - val_loss: 0.2980 - val_accuracy: 0.8535
# Epoch 2/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.2799 - accuracy: 0.8686 - val_loss: 0.1939 - val_accuracy: 0.8895
# Epoch 3/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.2100 - accuracy: 0.9014 - val_loss: 0.1487 - val_accuracy: 0.9342
# Epoch 4/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.1802 - accuracy: 0.9168 - val_loss: 0.2794 - val_accuracy: 0.8659
# Epoch 5/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.
200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0871 - accuracy: 0.9622 - val_loss: 0.1254 - val_accuracy: 0.9522
# Epoch 96/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0906 - accuracy: 0.9627 - val_loss: 0.1093 - val_accuracy: 0.9532
# Epoch 97/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0918 - accuracy: 0.9608 - val_loss: 0.0916 - val_accuracy: 0.9604
# Epoch 98/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0861 - accuracy: 0.9634 - val_loss: 0.0897 - val_accuracy: 0.9625
# Epoch 99/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0944 - accuracy: 0.9613 - val_loss: 0.1037 - val_accuracy: 0.9527
# Epoch 100/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0857 - accuracy: 0.9614 - val_loss: 0.0825 - val_accuracy: 0.9651
# Epoch 101/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0850 - accuracy: 0.9630 - val_loss: 0.0869 - val_accuracy: 0.9625
# Epoch 102/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0827 - accuracy: 0.9644 - val_loss: 0.0929 - val_accuracy: 0.9548
# Epoch 103/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0835 - accuracy: 0.9625 - val_loss: 0.0825 - val_accuracy: 0.9625
# Epoch 104/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0845 - accuracy: 0.9631 - val_loss: 0.0856 - val_accuracy: 0.9604
# Epoch 105/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0878 - accuracy: 0.9625 - val_loss: 0.0876 - val_accuracy: 0.9640
# Epoch 106/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0830 - accuracy: 0.9636 - val_loss: 0.0953 - val_accuracy: 0.9558
# Epoch 107/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0888 - accuracy: 0.9623 - val_loss: 0.0830 - val_accuracy: 0.9640
# Epoch 108/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0821 - accuracy: 0.9653 - val_loss: 0.0784 - val_accuracy: 0.9625
# Epoch 109/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.2632 - accuracy: 0.9545 - val_loss: 0.1014 - val_accuracy: 0.9568
# Epoch 110/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0862 - accuracy: 0.9641 - val_loss: 0.0931 - val_accuracy: 0.9579
# Epoch 111/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0839 - accuracy: 0.9643 - val_loss: 0.0887 - val_accuracy: 0.9661
# Epoch 112/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0820 - accuracy: 0.9648 - val_loss: 0.1068 - val_accuracy: 0.9553
# Epoch 113/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.1002 - accuracy: 0.9600 - val_loss: 0.1023 - val_accuracy: 0.9579
# Epoch 114/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0899 - accuracy: 0.9623 - val_loss: 0.0944 - val_accuracy: 0.9522
# Epoch 115/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0817 - accuracy: 0.9665 - val_loss: 0.0830 - val_accuracy: 0.9640
# Epoch 116/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0798 - accuracy: 0.9652 - val_loss: 0.0904 - val_accuracy: 0.9625
# Epoch 117/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0757 - accuracy: 0.9675 - val_loss: 0.0837 - val_accuracy: 0.9640
# Epoch 118/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0823 - accuracy: 0.9668 - val_loss: 0.2693 - val_accuracy: 0.8926
# Epoch 119/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.1365 - accuracy: 0.9464 - val_loss: 0.1018 - val_accuracy: 0.9568
# Epoch 120/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0857 - accuracy: 0.9614 - val_loss: 0.0922 - val_accuracy: 0.9558
# Epoch 121/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0857 - accuracy: 0.9650 - val_loss: 0.0862 - val_accuracy: 0.9594
# Epoch 122/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0839 - accuracy: 0.9608 - val_loss: 0.0857 - val_accuracy: 0.9640
# Epoch 123/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0776 - accuracy: 0.9663 - val_loss: 0.0861 - val_accuracy: 0.9609
# Epoch 124/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0836 - accuracy: 0.9658 - val_loss: 0.0786 - val_accuracy: 0.9625
# Epoch 125/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0798 - accuracy: 0.9652 - val_loss: 0.1062 - val_accuracy: 0.9543
# Epoch 126/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0865 - accuracy: 0.9632 - val_loss: 0.0891 - val_accuracy: 0.9568
# Epoch 127/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0819 - accuracy: 0.9643 - val_loss: 0.0985 - val_accuracy: 0.9522
# Epoch 128/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0831 - accuracy: 0.9656 - val_loss: 0.0778 - val_accuracy: 0.9676
# Epoch 129/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0808 - accuracy: 0.9649 - val_loss: 0.0920 - val_accuracy: 0.9589
# Epoch 130/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0856 - accuracy: 0.9629 - val_loss: 0.0856 - val_accuracy: 0.9579
# Epoch 131/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0766 - accuracy: 0.9663 - val_loss: 0.1050 - val_accuracy: 0.9573
# Epoch 132/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0890 - accuracy: 0.9638 - val_loss: 0.1127 - val_accuracy: 0.9466
# Epoch 133/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0791 - accuracy: 0.9659 - val_loss: 0.0845 - val_accuracy: 0.9635
# Epoch 134/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0763 - accuracy: 0.9658 - val_loss: 0.0812 - val_accuracy: 0.9676
# Epoch 135/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0840 - accuracy: 0.9631 - val_loss: 0.1137 - val_accuracy: 0.9471
# Epoch 136/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0739 - accuracy: 0.9689 - val_loss: 0.0855 - val_accuracy: 0.9615
# Epoch 137/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0801 - accuracy: 0.9665 - val_loss: 0.1710 - val_accuracy: 0.9239
# Epoch 138/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0844 - accuracy: 0.9629 - val_loss: 0.0992 - val_accuracy: 0.9579
# Epoch 139/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0832 - accuracy: 0.9648 - val_loss: 0.0803 - val_accuracy: 0.9635
# Epoch 140/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0820 - accuracy: 0.9663 - val_loss: 0.0932 - val_accuracy: 0.9620
# Epoch 141/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0796 - accuracy: 0.9666 - val_loss: 0.0800 - val_accuracy: 0.9599
# Epoch 142/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0855 - accuracy: 0.9632 - val_loss: 0.0893 - val_accuracy: 0.9512
# Epoch 143/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0927 - accuracy: 0.9605 - val_loss: 0.1279 - val_accuracy: 0.9435
# Epoch 144/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0822 - accuracy: 0.9641 - val_loss: 0.0765 - val_accuracy: 0.9692
# Epoch 145/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0754 - accuracy: 0.9692 - val_loss: 0.0807 - val_accuracy: 0.9661
# Epoch 146/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0736 - accuracy: 0.9684 - val_loss: 0.0947 - val_accuracy: 0.9548
# Epoch 147/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0817 - accuracy: 0.9643 - val_loss: 0.0806 - val_accuracy: 0.9666
# Epoch 148/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0771 - accuracy: 0.9685 - val_loss: 0.0830 - val_accuracy: 0.9609
# Epoch 149/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0803 - accuracy: 0.9672 - val_loss: 0.0833 - val_accuracy: 0.9645
# Epoch 150/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0781 - accuracy: 0.9650 - val_loss: 0.0715 - val_accuracy: 0.9687
# Epoch 151/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0754 - accuracy: 0.9683 - val_loss: 0.0838 - val_accuracy: 0.9584
# Epoch 152/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.1273 - accuracy: 0.9603 - val_loss: 0.0852 - val_accuracy: 0.9604
# Epoch 153/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0845 - accuracy: 0.9648 - val_loss: 0.0897 - val_accuracy: 0.9615
# Epoch 154/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0755 - accuracy: 0.9683 - val_loss: 0.0950 - val_accuracy: 0.9532
# Epoch 155/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0742 - accuracy: 0.9676 - val_loss: 0.0796 - val_accuracy: 0.9651
# Epoch 156/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0762 - accuracy: 0.9658 - val_loss: 0.0769 - val_accuracy: 0.9666
# Epoch 157/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0798 - accuracy: 0.9638 - val_loss: 0.0853 - val_accuracy: 0.9589
# Epoch 158/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0848 - accuracy: 0.9612 - val_loss: 0.0778 - val_accuracy: 0.9635
# Epoch 159/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0764 - accuracy: 0.9685 - val_loss: 0.0857 - val_accuracy: 0.9656
# Epoch 160/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0750 - accuracy: 0.9675 - val_loss: 0.0806 - val_accuracy: 0.9625
# Epoch 161/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0749 - accuracy: 0.9672 - val_loss: 0.0836 - val_accuracy: 0.9615
# Epoch 162/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0786 - accuracy: 0.9692 - val_loss: 0.0967 - val_accuracy: 0.9615
# Epoch 163/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0742 - accuracy: 0.9685 - val_loss: 0.1159 - val_accuracy: 0.9538
# Epoch 164/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0758 - accuracy: 0.9672 - val_loss: 0.0814 - val_accuracy: 0.9609
# Epoch 165/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0725 - accuracy: 0.9688 - val_loss: 0.0788 - val_accuracy: 0.9640
# Epoch 166/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0770 - accuracy: 0.9686 - val_loss: 0.0838 - val_accuracy: 0.9615
# Epoch 167/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0818 - accuracy: 0.9638 - val_loss: 0.0879 - val_accuracy: 0.9599
# Epoch 168/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.1057 - accuracy: 0.9614 - val_loss: 0.0906 - val_accuracy: 0.9604
# Epoch 169/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0736 - accuracy: 0.9699 - val_loss: 0.0776 - val_accuracy: 0.9671
# Epoch 170/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0702 - accuracy: 0.9689 - val_loss: 0.0928 - val_accuracy: 0.9579
# Epoch 171/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0742 - accuracy: 0.9688 - val_loss: 0.0779 - val_accuracy: 0.9645
# Epoch 172/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0725 - accuracy: 0.9672 - val_loss: 0.0747 - val_accuracy: 0.9666
# Epoch 173/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0716 - accuracy: 0.9692 - val_loss: 0.0869 - val_accuracy: 0.9651
# Epoch 174/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0696 - accuracy: 0.9708 - val_loss: 0.0994 - val_accuracy: 0.9563
# Epoch 175/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0712 - accuracy: 0.9679 - val_loss: 0.0808 - val_accuracy: 0.9656
# Epoch 176/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0805 - accuracy: 0.9676 - val_loss: 0.0874 - val_accuracy: 0.9589
# Epoch 177/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0736 - accuracy: 0.9699 - val_loss: 0.0901 - val_accuracy: 0.9615
# Epoch 178/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0692 - accuracy: 0.9694 - val_loss: 0.0767 - val_accuracy: 0.9666
# Epoch 179/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0847 - accuracy: 0.9631 - val_loss: 0.0792 - val_accuracy: 0.9651
# Epoch 180/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0777 - accuracy: 0.9662 - val_loss: 0.1335 - val_accuracy: 0.9455
# Epoch 181/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0784 - accuracy: 0.9685 - val_loss: 0.1092 - val_accuracy: 0.9496
# Epoch 182/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0701 - accuracy: 0.9692 - val_loss: 0.0761 - val_accuracy: 0.9651
# Epoch 183/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0749 - accuracy: 0.9684 - val_loss: 0.0726 - val_accuracy: 0.9676
# Epoch 184/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0709 - accuracy: 0.9683 - val_loss: 0.1005 - val_accuracy: 0.9553
# Epoch 185/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0729 - accuracy: 0.9690 - val_loss: 0.0860 - val_accuracy: 0.9651
# Epoch 186/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0759 - accuracy: 0.9686 - val_loss: 0.1492 - val_accuracy: 0.9404
# Epoch 187/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.9631 - val_loss: 0.0794 - val_accuracy: 0.9651
# Epoch 188/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0721 - accuracy: 0.9686 - val_loss: 0.0789 - val_accuracy: 0.9635
# Epoch 189/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0765 - accuracy: 0.9686 - val_loss: 0.0778 - val_accuracy: 0.9671
# Epoch 190/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0694 - accuracy: 0.9716 - val_loss: 0.0813 - val_accuracy: 0.9687
# Epoch 191/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0660 - accuracy: 0.9722 - val_loss: 0.0776 - val_accuracy: 0.9661
# Epoch 192/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0744 - accuracy: 0.9699 - val_loss: 0.0981 - val_accuracy: 0.9568
# Epoch 193/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0708 - accuracy: 0.9685 - val_loss: 0.0982 - val_accuracy: 0.9656
# Epoch 194/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0762 - accuracy: 0.9665 - val_loss: 0.0775 - val_accuracy: 0.9671
# Epoch 195/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0688 - accuracy: 0.9715 - val_loss: 0.1030 - val_accuracy: 0.9568
# Epoch 196/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0746 - accuracy: 0.9674 - val_loss: 0.1477 - val_accuracy: 0.9512
# Epoch 197/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0676 - accuracy: 0.9710 - val_loss: 0.0826 - val_accuracy: 0.9553
# Epoch 198/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0860 - accuracy: 0.9654 - val_loss: 0.0822 - val_accuracy: 0.9640
# Epoch 199/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0729 - accuracy: 0.9688 - val_loss: 0.0875 - val_accuracy: 0.9635
# Epoch 200/200
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0764 - accuracy: 0.9654 - val_loss: 0.0955 - val_accuracy: 0.9543

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(X_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(X_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9651449918746948
# Testing Accuracy:  0.9601151347160339

# %%
preds = model.predict(X_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=4 # number of classes

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

#Y_pred = model.predict(X_test)
#Y_pred_classes = np.argmax(Y_pred,axis = 1) 
#Y_true = np.argmax(y_test,axis = 0) 

#confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
confusion_mtx = confusion_matrix(classpreds, y_testclass) 
f,ax = plt.subplots(figsize=(8, 8))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="Greens",linecolor="gray", fmt= '.1f',ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Confusion Matrix
c_names = ['normal', 'misalignment', 'unbalance', 'bearing']
cm = confusion_matrix (classpreds, y_testclass)
print(cm)

# Get percentage value for each element of the matrix
cm_sum = np.sum(cm, axis=1, keepdims=True)
cm_perc = cm / cm_sum.astype(float) * 100
annot = np.empty_like(cm).astype(str)
nrows, ncols = cm.shape
for i in range(nrows):
    for j in range(ncols):
        c = cm[i, j]
        p = cm_perc[i, j]
        if i == j:
            s = cm_sum[i]
            annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
        elif c == 0:
            annot[i, j] = ''
        else:
            annot[i, j] = '%.1f%%\n%d' % (p, c)

# Display confusion matrix 
df_cm = pd.DataFrame(cm, index = c_names, columns = c_names)
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
fig, ax = plt.subplots(figsize=(10,7))
sns.heatmap(df_cm, annot=annot, fmt='')
# Out:
# [[772   0   0   0]
#  [417   0   0   0]
#  [771   0   0   0]
#  [472   0   0   0]]
# <AxesSubplot:xlabel='Predicted', ylabel='Actual'>
